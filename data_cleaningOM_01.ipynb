# %%
# Package import
import pandas as pd
import numpy as np

# %%
# Load dataframe
df = pd.read_csv(r"D:\otodom_regression\data_scraping.csv", sep=';')

# %%
df.head()
# Out:
#                                                Tytul     Cena  \
# 0                            Apartament na Mokotowie  1900000
# 1     Konstancin-Jeziorna, dwupokojowe, BEZPOŚREDNIO   435000
# 2  Sprzedam 2 pokojowe mieszkanie 38m2 bezpośrednio!   531962
# 3                    2 pokoje w cudownej lokalizacji   429000
# 4   Bezpośrednio 37. 24m2,Metro Wawrzyszew ,2 pokoje   514000
#
#                                          Lokalizacja  \
# 0                 Warszawa, Mokotów, ul. Cybernetyki
# 1  ul. Wilanowska 12, Osiedle Grapa, Konstancin-J...
# 2                       Warszawa, Wola, ul. Pawia 32
# 3         Warszawa, Bemowo, ul. Mieczysława Wolfkego
# 4                 Warszawa, Bielany, ul. Przy Agorze
#
#                                                  URL Powierzchnia  \
# 0  https://www.otodom.pl/pl/oferta/apartament-na-...       100 m²
# 1  https://www.otodom.pl/pl/oferta/konstancin-jez...        46 m²
# 2  https://www.otodom.pl/pl/oferta/sprzedam-2-pok...        38 m²
# 3  https://www.otodom.pl/pl/oferta/2-pokoje-w-cud...        36 m²
# 4  https://www.otodom.pl/pl/oferta/bezposrednio-3...     37,24 m²
#
#          Forma własności Liczba pokoi Stan wykończenia Piętro  \
# 0         pełna własność           4   do zamieszkania    2/6
# 1         pełna własność           2        do remontu    2/3
# 2         pełna własność           2   do zamieszkania    3/3
# 3  spółdzielcze wł. z KW           2   do zamieszkania   8/10
# 4         pełna własność           2   do zamieszkania   4/10
#
#   Balkon / ogród / taras  ...      Dostępne od       Rok budowy  \
# 0                 balkon  ...  brak informacji  brak informacji
# 1                zapytaj  ...  brak informacji             1950
# 2                 balkon  ...  brak informacji  brak informacji
# 3                 balkon  ...  brak informacji             1980
# 4                zapytaj  ...  brak informacji             1968
#
#    Rodzaj zabudowy        Okna Winda                                 Media  \
# 0  apartamentowiec  aluminiowe   tak                       brak informacji
# 1        kamienica  plastikowe   nie  telewizja kablowa, internet, telefon
# 2             blok  plastikowe   nie           telewizja kablowa, internet
# 3             blok  plastikowe   tak           telewizja kablowa, internet
# 4             blok  plastikowe   tak           telewizja kablowa, internet
#
#                                       Zabezpieczenia  \
# 0  drzwi / okna antywłamaniowe, teren zamknięty, ...
# 1    drzwi / okna antywłamaniowe, domofon / wideofon
# 2                                 domofon / wideofon
# 3                                 domofon / wideofon
# 4           domofon / wideofon, monitoring / ochrona
#
#                                          Wyposażenie  \
# 0  zmywarka, lodówka, meble, piekarnik, kuchenka,...
# 1                                    brak informacji
# 2  zmywarka, lodówka, meble, piekarnik, kuchenka,...
# 3        lodówka, meble, piekarnik, kuchenka, pralka
# 4                                    brak informacji
#
#          Informacje dodatkowe Materiał budynku
# 0             brak informacji            cegła
# 1  piwnica, oddzielna kuchnia            cegła
# 2  piwnica, oddzielna kuchnia            cegła
# 3  piwnica, oddzielna kuchnia     wielka płyta
# 4             brak informacji     wielka płyta
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Tytul', 'Cena', 'Lokalizacja', 'URL', 'Powierzchnia',
#        'Forma własności', 'Liczba pokoi', 'Stan wykończenia', 'Piętro',
#        'Balkon / ogród / taras', 'Czynsz', 'Miejsce parkingowe',
#        'Obsługa zdalna', 'Ogrzewanie', 'Rynek', 'Typ ogłoszeniodawcy',
#        'Dostępne od', 'Rok budowy', 'Rodzaj zabudowy', 'Okna', 'Winda',
#        'Media', 'Zabezpieczenia', 'Wyposażenie', 'Informacje dodatkowe',
#        'Materiał budynku'],
#       dtype='object')

# %%
df.describe()
# Out:
#                        Tytul          Cena          Lokalizacja  \
# count                  24180         24180                24180
# unique                 22428          4881                 4820
# top     Apartament Z Ogrodem  Zapytaj o ce  Warszawa, Białołęka
# freq                      38          5208                 1087
#
#                                                       URL Powierzchnia  \
# count                                               24180        24180
# unique                                              24131         4988
# top     https://www.otodom.pl/pl/oferta/ochota-ul-dick...        48 m²
# freq                                                    2          289
#
#        Forma własności Liczba pokoi Stan wykończenia Piętro  \
# count            24180        24180            24180  24180
# unique               5           10                4    269
# top     pełna własność           3           zapytaj      1
# freq             11343         9137            11035   1450
#
#        Balkon / ogród / taras  ...      Dostępne od Rok budowy  \
# count                   24180  ...            18897      18897
# unique                      9  ...              408        147
# top                    balkon  ...  brak informacji       2022
# freq                    13454  ...            16241       2801
#
#        Rodzaj zabudowy        Okna  Winda            Media   Zabezpieczenia  \
# count            18897       18897  18897            18897            18897
# unique               8           4      2                9               52
# top               blok  plastikowe    tak  brak informacji  brak informacji
# freq              8665        9573  11140             9915             8646
#
#             Wyposażenie Informacje dodatkowe Materiał budynku
# count             18897                18897            18897
# unique               92                   16               11
# top     brak informacji      brak informacji  brak informacji
# freq              13632                 9968             8871
#
# [4 rows x 26 columns]

# %%
# Remove adds with no price
df_clear = df[df['Cena'] != 'Zapytaj o ce']

# %%
# Tytuł:
df_clear['Tytul']
# Out:
# 0                                  Apartament na Mokotowie
# 1           Konstancin-Jeziorna, dwupokojowe, BEZPOŚREDNIO
# 2        Sprzedam 2 pokojowe mieszkanie 38m2 bezpośrednio!
# 3                          2 pokoje w cudownej lokalizacji
# 4         Bezpośrednio 37. 24m2,Metro Wawrzyszew ,2 pokoje
#                                ...
# 24175    Dwupoziomowe PARTERiPODDASZE 2 ŁAZIENKI 2msc p...
# 24176    Dwupoziomowe PARTERiPODDASZE 2 ŁAZIENKI 2msc p...
# 24177    DWAPOZIOMY mieszkania bezczynszowe WOLA MROKOWSKA
# 24178        Dwa poziomy Mieszkania ogródek WOLA MROKOWSKA
# 24179    LOKALE dwupoziomowe 2 msc.postojowe 5 pokoi WO...
# Name: Tytul, Length: 18972, dtype: object

# %%
# Add title string length and remove title
df_clear['Title_len'] = df_clear['Tytul'].apply(lambda x: len(x))
# Out:
# C:\Users\Marcin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_clear = df_clear.drop(columns=['Tytul'])

# %%
# Cena
df_clear['Cena'].value_counts()
# Out:
# 599000    183
# 550000    181
# 499000    178
# 699000    173
# 650000    161
#          ...
# 544920      1
# 560363      1
# 529542      1
# 40000       1
# 294137      1
# Name: Cena, Length: 4880, dtype: int64

# %%
# Convert price to float
df_clear['Cena'] = df_clear['Cena'].apply(lambda x: float(x.replace(',', '.')))

# %%
df_clear['Cena']
# Out:
# 0        1900000.0
# 1         435000.0
# 2         531962.0
# 3         429000.0
# 4         514000.0
#            ...
# 24175     429000.0
# 24176     429000.0
# 24177     419000.0
# 24178     419000.0
# 24179     419000.0
# Name: Cena, Length: 18972, dtype: float64

# %%
df_clear.iloc[0:100]
# Out:
#           Cena                                        Lokalizacja  \
# 0    1900000.0                 Warszawa, Mokotów, ul. Cybernetyki
# 1     435000.0  ul. Wilanowska 12, Osiedle Grapa, Konstancin-J...
# 2     531962.0                       Warszawa, Wola, ul. Pawia 32
# 3     429000.0         Warszawa, Bemowo, ul. Mieczysława Wolfkego
# 4     514000.0                 Warszawa, Bielany, ul. Przy Agorze
# ..         ...                                                ...
# 124   610000.0                        Warszawa, Mokotów, Santocka
# 125   680000.0                                     Warszawa, Wola
# 126   550000.0                                     Warszawa, Wola
# 127   900000.0  Warszawa, Praga-Południe, Gocław, ul. gen. Rom...
# 128   529000.0                Warszawa, Wola, ul. Górczewska 116a
#
#                                                    URL Powierzchnia  \
# 0    https://www.otodom.pl/pl/oferta/apartament-na-...       100 m²
# 1    https://www.otodom.pl/pl/oferta/konstancin-jez...        46 m²
# 2    https://www.otodom.pl/pl/oferta/sprzedam-2-pok...        38 m²
# 3    https://www.otodom.pl/pl/oferta/2-pokoje-w-cud...        36 m²
# 4    https://www.otodom.pl/pl/oferta/bezposrednio-3...     37,24 m²
# ..                                                 ...          ...
# 124  https://www.otodom.pl/pl/oferta/w-sasiedztwie-...     46,71 m²
# 125  https://www.otodom.pl/pl/oferta/mieszkanie-46-...     46,78 m²
# 126  https://www.otodom.pl/pl/oferta/mieszkanie-29-...        29 m²
# 127  https://www.otodom.pl/pl/oferta/goclaw-gen-r-a...        80 m²
# 128  https://www.otodom.pl/pl/oferta/mieszkanie-wol...      37,1 m²
#
#                Forma własności Liczba pokoi Stan wykończenia     Piętro  \
# 0               pełna własność           4   do zamieszkania        2/6
# 1               pełna własność           2        do remontu        2/3
# 2               pełna własność           2   do zamieszkania        3/3
# 3        spółdzielcze wł. z KW           2   do zamieszkania       8/10
# 4               pełna własność           2   do zamieszkania       4/10
# ..                         ...          ...              ...        ...
# 124                    zapytaj           2           zapytaj        1/3
# 125             pełna własność           3           zapytaj    > 10/11
# 126             pełna własność           1           zapytaj        3/4
# 127  spółdzielcze własnościowe           4        do remontu        7/8
# 128      spółdzielcze wł. z KW           2   do zamieszkania  parter/10
#
#     Balkon / ogród / taras   Czynsz  ...       Rok budowy  Rodzaj zabudowy  \
# 0                   balkon  zapytaj  ...  brak informacji  apartamentowiec
# 1                  zapytaj   200 zł  ...             1950        kamienica
# 2                   balkon   450 zł  ...  brak informacji             blok
# 3                   balkon   500 zł  ...             1980             blok
# 4                  zapytaj   370 zł  ...             1968             blok
# ..                     ...      ...  ...              ...              ...
# 124                 balkon   500 zł  ...             2015             blok
# 125                 balkon  zapytaj  ...             1974             blok
# 126                 balkon   350 zł  ...             2018  apartamentowiec
# 127          balkon, taras   670 zł  ...             1996             blok
# 128                 balkon   500 zł  ...             1973             blok
#
#                 Okna Winda                                 Media  \
# 0         aluminiowe   tak                       brak informacji
# 1         plastikowe   nie  telewizja kablowa, internet, telefon
# 2         plastikowe   nie           telewizja kablowa, internet
# 3         plastikowe   tak           telewizja kablowa, internet
# 4         plastikowe   tak           telewizja kablowa, internet
# ..               ...   ...                                   ...
# 124  brak informacji   tak                       brak informacji
# 125  brak informacji   tak                       brak informacji
# 126  brak informacji   tak                       brak informacji
# 127       plastikowe   tak                               telefon
# 128       plastikowe   tak                       brak informacji
#
#                                         Zabezpieczenia  \
# 0    drzwi / okna antywłamaniowe, teren zamknięty, ...
# 1      drzwi / okna antywłamaniowe, domofon / wideofon
# 2                                   domofon / wideofon
# 3                                   domofon / wideofon
# 4             domofon / wideofon, monitoring / ochrona
# ..                                                 ...
# 124                                 domofon / wideofon
# 125                                    brak informacji
# 126                                    brak informacji
# 127  drzwi / okna antywłamaniowe, domofon / wideofo...
# 128    drzwi / okna antywłamaniowe, domofon / wideofon
#
#                                            Wyposażenie  \
# 0    zmywarka, lodówka, meble, piekarnik, kuchenka,...
# 1                                      brak informacji
# 2    zmywarka, lodówka, meble, piekarnik, kuchenka,...
# 3          lodówka, meble, piekarnik, kuchenka, pralka
# 4                                      brak informacji
# ..                                                 ...
# 124                                    brak informacji
# 125                                    brak informacji
# 126                                    brak informacji
# 127                                    brak informacji
# 128  zmywarka, lodówka, meble, piekarnik, kuchenka,...
#
#            Informacje dodatkowe Materiał budynku Title_len
# 0               brak informacji            cegła        23
# 1    piwnica, oddzielna kuchnia            cegła        46
# 2    piwnica, oddzielna kuchnia            cegła        49
# 3    piwnica, oddzielna kuchnia     wielka płyta        31
# 4               brak informacji     wielka płyta        48
# ..                          ...              ...       ...
# 124             brak informacji  brak informacji        32
# 125             brak informacji     wielka płyta        30
# 126             brak informacji            cegła        27
# 127  piwnica, oddzielna kuchnia            cegła        50
# 128  piwnica, oddzielna kuchnia     wielka płyta        48
#
# [100 rows x 26 columns]
